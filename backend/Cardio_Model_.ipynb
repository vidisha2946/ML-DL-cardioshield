# %%
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
print(sklearn.__version__)
# Out:
# 1.5.1

# %%
df = pd.read_csv('./data/cardio_processed_data.csv')
df
# Out:
#        age  gender  height  weight        bmi  ap_hi  ap_lo  cholesterol  \
# 0       50       1     168    62.0  21.967120    110     80            1
# 1       55       0     156    85.0  34.927679    140     90            3
# 2       51       0     165    64.0  23.507805    130     70            3
# 3       48       1     169    82.0  28.710479    150    100            1
# 4       47       0     156    56.0  23.011177    100     60            1
# ...    ...     ...     ...     ...        ...    ...    ...          ...
# 68545   52       1     168    76.0  26.927438    120     80            1
# 68546   61       0     158   126.0  50.472681    140     90            2
# 68547   52       1     183   105.0  31.353579    180     90            3
# 68548   61       0     163    72.0  27.099251    135     80            1
# 68549   56       0     170    72.0  24.913495    120     80            2
#
#        gluc  smoke  alco  active  pulse_pressure  cardio
# 0         1      0     0       1              30       0
# 1         1      0     0       1              50       1
# 2         1      0     0       0              60       1
# 3         1      0     0       1              50       1
# 4         1      0     0       0              40       0
# ...     ...    ...   ...     ...             ...     ...
# 68545     1      1     0       1              40       0
# 68546     2      0     0       1              50       1
# 68547     1      0     1       0              90       1
# 68548     2      0     0       0              55       1
# 68549     1      0     0       1              40       0
#
# [68550 rows x 14 columns]

# %%
plt.scatter(df['height'] , df['cardio'])

# %%
plt.scatter(df['weight'] , df['cardio'])

# %%
plt.scatter(df['bmi'] , df['cardio'])

# %%
plt.scatter(df['ap_hi'] , df['cardio'])

# %%
df.head()
# Out:
#    age  gender  height  weight        bmi  ap_hi  ap_lo  cholesterol  gluc  \
# 0   50       1     168    62.0  21.967120    110     80            1     1
# 1   55       0     156    85.0  34.927679    140     90            3     1
# 2   51       0     165    64.0  23.507805    130     70            3     1
# 3   48       1     169    82.0  28.710479    150    100            1     1
# 4   47       0     156    56.0  23.011177    100     60            1     1
#
#    smoke  alco  active  pulse_pressure  cardio
# 0      0     0       1              30       0
# 1      0     0       1              50       1
# 2      0     0       0              60       1
# 3      0     0       1              50       1
# 4      0     0       0              40       0

# %%
df['cardio'].value_counts(normalize=True)
# Out:
# cardio
# 0    0.505062
# 1    0.494938
# Name: proportion, dtype: float64

# %%
x = df.drop('cardio',axis=1)

# %%
y = df['cardio']

# %%
x.head()
# Out:
#    age  gender  height  weight        bmi  ap_hi  ap_lo  cholesterol  gluc  \
# 0   50       1     168    62.0  21.967120    110     80            1     1
# 1   55       0     156    85.0  34.927679    140     90            3     1
# 2   51       0     165    64.0  23.507805    130     70            3     1
# 3   48       1     169    82.0  28.710479    150    100            1     1
# 4   47       0     156    56.0  23.011177    100     60            1     1
#
#    smoke  alco  active  pulse_pressure
# 0      0     0       1              30
# 1      0     0       1              50
# 2      0     0       0              60
# 3      0     0       1              50
# 4      0     0       0              40

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: cardio, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=50)

# %%
# len(x_train)
x_train.shape
# Out:
# (54840, 13)

# %%
# len(x_test)
x_test.shape
# Out:
# (13710, 13)

# %%
x_train
# Out:
#        age  gender  height  weight        bmi  ap_hi  ap_lo  cholesterol  \
# 568     51       1     160    63.0  24.609375    170     90            1
# 46039   60       1     170    70.0  24.221453    110     70            1
# 52071   58       0     160    60.0  23.437500    130     80            1
# 59098   53       0     154    67.0  28.250970    130     90            2
# 55073   42       0     170    69.0  23.875433    120     80            1
# ...    ...     ...     ...     ...        ...    ...    ...          ...
# 59417   59       0     168    70.0  24.801587    125     80            1
# 64770   61       1     172    70.0  23.661439    120     80            1
# 35948   60       1     171    71.0  24.280975    120     70            1
# 38672   56       0     160   100.0  39.062500    120     80            1
# 1551    57       0     162    61.0  23.243408    150     90            2
#
#        gluc  smoke  alco  active  pulse_pressure
# 568       1      0     0       0              80
# 46039     1      0     0       1              40
# 52071     2      0     0       1              50
# 59098     1      0     0       1              40
# 55073     1      0     0       0              40
# ...     ...    ...   ...     ...             ...
# 59417     1      0     1       1              45
# 64770     1      0     0       0              40
# 35948     1      0     0       1              50
# 38672     1      0     0       1              40
# 1551      1      0     0       1              60
#
# [54840 rows x 13 columns]

# %%
y_train
# Out:
# 568      1
# 46039    1
# 52071    0
# 59098    1
# 55073    0
#         ..
# 59417    0
# 64770    1
# 35948    0
# 38672    1
# 1551     1
# Name: cardio, Length: 54840, dtype: int64

# %%
clf = LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = clf.predict(x_test)
